# %%
25/11/1095      :       Clermont                           :      Urbano II    
1097            :       Nicea                              :      Crociati     
1098            :       Antiochia                          :      Crociati   
1098            :       Edessa                             :      Baldovino Delle Fiandre
Luglio 1099     :       Gerusalemme                        :      Crociati
Dicembre 1144   :       Edessa                             :      Imad-Al-Din Zengi(Governatore di Aleppo e Mosul)
1148            :       Damasco                            :      Luigi VII e Corrado III
1187            :       Gerusalemme                        :      Saladino
10/06/1190      :       Fiume Goksu(Asia Minore)           :      Federico Barbarossa
#Agosto 1191    :       Terra Santa                        :      Filippo Augusto
#9/10/1192      :       Terra Santa                        :      Riccardo D'Inghilterra
8/01/1198       :       Città del Vaticano                 :      Papa Innocenzo III
15/08/1198      :       Città del Vaticano                 :      Papa Innocenzo III
1199            :       Ecry-Sur-Seine                     :      Tebaldo III di Champagne
1/10/1202       :       Venezia (oppure 8/11/1202)         :      Crociati e Veneziani
10/11/1202      :       Zara                               :      Crociati e Veneziani
1203            :       Costantinopoli                     :      Crociati e Veneziani
1204            :       Costantinopoli                     :      Crociati e Veneziani
1261            :       Costantinopoli                     :      Bizantini

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

x=["25/11/1095","1097","1098","1098","Lug 1099","Dic 1144","1148","1187","10/06/1190","Ag 1191","9/10/1192","8/01/1198","15/08/1198","1199","*1/10/1202","10/11/1202","1203","1204","1261"]
y=["Clermont","Nicea","Antiochia","Edessa","Gerusalemme","Edessa","Damasco","Gerusalemme","Fiume Goksu","Terra Santa","Terra Santa","Città del Vaticano","Città del Vaticano","Ecry-sur-Seine","Venezia","Zara","Costantinopoli","Costantinopoli","Costantinopoli"]

figure(figsize=(24, 10), dpi=80)

plt.plot(x, y,'ro')

plt.rcParams.update({'font.size': 8})

# text is left-aligned
font = {'family': 'serif',
        'color':  'black',
        'weight': 'bold',
        'size': 16,
        }

plt.text("25/11/1095","Clermont",' (1)',fontdict=font)
plt.text("1097","Nicea",' (2)',fontdict=font)
plt.text("1098","Antiochia",' (3)',fontdict=font)
plt.text("1098","Edessa",' (4)',fontdict=font)
plt.text("Lug 1099","Gerusalemme",' (5)',fontdict=font)
plt.text("Dic 1144","Edessa",' (6)',fontdict=font)
plt.text("1148","Damasco",' (7)',fontdict=font)
plt.text("1187","Gerusalemme",' (8)',fontdict=font)
plt.text("10/06/1190","Fiume Goksu",' (9)',fontdict=font)
plt.text("Ag 1191","Terra Santa",' (10)',fontdict=font)
plt.text("9/10/1192","Terra Santa",' (11)',fontdict=font)
plt.text("8/01/1198","Città del Vaticano",' (12)',fontdict=font)
plt.text("15/08/1198","Città del Vaticano",' (13)',fontdict=font)
plt.text("1199","Ecry-sur-Seine",' (14)',fontdict=font)
plt.text("*1/10/1202","Venezia",' (15)',fontdict=font)
plt.text("10/11/1202","Zara",' (16)',fontdict=font)
plt.text("1203","Costantinopoli",' (17)',fontdict=font)
plt.text("1204","Costantinopoli",' (18)',fontdict=font)
plt.text("1261","Costantinopoli",' (19)',fontdict=font)

font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal',
        'size': 10,
        }

plt.text(-1,-2,"*secondo alcune fonti la vera data è 8/11/1202",fontdict=font)

plt.grid()
#plt.show()

plt.savefig("Luighi.pdf", bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

x=["25/11/1095","1097","1098","1098","Lug 1099","Dic 1144","1148","1187","10/06/1190","Ag 1191","9/10/1192","8/01/1198","15/08/1198","1199","*1/10/1202","10/11/1202","1203","1204","1261"]
y=["Urbano II","Crociati","Crociati","B. Delle Fiandre","Crociati","Imad-Al-Din-Zengi","Luigi VII e Corrado III","Saladino","Federico Barbarossa","Filippo Augusto","Riccardo D'Inghilterra","Innocenzo III","Innocenzo III","Tebaldo III di Champagne","Crociati e Veneziani","Crociati e Veneziani","Crociati e Veneziani","Crociati e Veneziani","Bizantini"]

figure(figsize=(24, 10), dpi=80)

plt.plot(x, y,'ro')

plt.rcParams.update({'font.size': 8})

# text is left-aligned
font = {'family': 'serif',
        'color':  'black',
        'weight': 'bold',
        'size': 16,
        }

plt.text("25/11/1095","Urbano II",' (1)',fontdict=font)
plt.text("1097","Crociati",' (2)',fontdict=font)
plt.text("1098","Crociati",' (3)',fontdict=font)
plt.text("1098","B. Delle Fiandre",' (4)',fontdict=font)
plt.text("Lug 1099","Crociati",' (5)',fontdict=font)
plt.text("Dic 1144","Imad-Al-Din-Zengi",' (6)',fontdict=font)
plt.text("1148","Luigi VII e Corrado III",' (7)',fontdict=font)
plt.text("1187","Saladino",' (8)',fontdict=font)
plt.text("10/06/1190","Federico Barbarossa",' (9)',fontdict=font)
plt.text("Ag 1191","Filippo Augusto",' (10)',fontdict=font)
plt.text("9/10/1192","Riccardo D'Inghilterra",' (11)',fontdict=font)
plt.text("8/01/1198","Innocenzo III",' (12)',fontdict=font)
plt.text("15/08/1198","Innocenzo III",' (13)',fontdict=font)
plt.text("1199","Tebaldo III di Champagne",' (14)',fontdict=font)
plt.text("*1/10/1202","Crociati e Veneziani",' (15)',fontdict=font)
plt.text("10/11/1202","Crociati e Veneziani",' (16)',fontdict=font)
plt.text("1203","Crociati e Veneziani",' (17)',fontdict=font)
plt.text("1204","Crociati e Veneziani",' (18)',fontdict=font)
plt.text("1261","Bizantini",' (19)',fontdict=font)

font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal',
        'size': 10,
        }

plt.text(-1,-2,"*secondo alcune fonti la vera data è 8/11/1202",fontdict=font)

plt.grid()
#plt.show()

plt.savefig("Soggetti.pdf", bbox_inches='tight')
